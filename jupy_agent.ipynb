# %% [markdown]
# # Jup Project
# #### Task 1 <br> Gwendeline Zakhour
# ### What: This notebook contains tests and trial and errors of ai agents
# ____________________________________________________________________________________________
# <!-- This is a comment and will NOT be shown in the rendered Markdown -->
# <!-- H with space for headers>
# <!-- <br> for ignoring spaces -->

# %% [markdown]
# # 1.0 Imports

# %%
# %pip install pandas SQLAlchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import func
# Out:
# 10

# %%
import pandas as pd
df = pd.DataFrame({"a": [1,2], "b": [3,4]})
print(df)
# Out:
#    a  b
# 0  1  3
# 1  2  4
